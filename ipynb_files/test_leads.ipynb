# %%
from simple_salesforce import Salesforce
import pandas as pd
from dotenv import load_dotenv
from datetime import date, timedelta
from sqlalchemy import create_engine
from urllib.parse import quote_plus
from functools import lru_cache
import re
import os

# %%
load_dotenv()

username = os.getenv("PG_USERNAME")
password = os.getenv("PG_PASSWORD")
host = os.getenv("PG_HOST")
port = os.getenv("PG_PORT")
database = os.getenv("PG_DATABASE_EXPORT")

# URL-encode the password
encoded_password = quote_plus(password)

engine = create_engine(
    f"postgresql+psycopg2://{username}:{encoded_password}@{host}:{port}/{database}"
)

# %%
engine
# Out:
# Engine(postgresql+psycopg2://insights:***@10.99.64.56:5432/marcomm_db)

# %%
query = """
SELECT *
FROM leads_opp_staging
"""

# %%
df = pd.read_sql_table("leads_opp_staging", con=engine, schema="staging")

# %%
result = df.groupby('reporting_date')['id'].count().reset_index()

# %%
result
# Out:
#     reporting_date     id
# 0       2023-10-27  10088
# 1       2023-11-03  10710
# 2       2023-11-10  11498
# 3       2023-11-17  12377
# 4       2023-11-24  13937
# ..             ...    ...
# 99      2025-09-19  68446
# 100     2025-09-26  68294
# 101     2025-10-03  68578
# 102     2025-10-10  67897
# 103     2025-10-17  67754
#
# [104 rows x 2 columns]

# %%
df.tail(10)
# Out:
#                          id reporting_date  type    record_type  \
# 1076445  00QMg000009VN3BMAW     2025-10-17  Lead  Non-Malaysian
# 1102917  00QMg00000E2mGbMAJ     2025-10-17  Lead  Non-Malaysian
# 1083354  00QMg00000BKN8bMAH     2025-10-17  Lead      Malaysian
# 1076446  00QMg000009vnjaMAA     2025-10-17  Lead      Malaysian
# 1083355  00QMg00000BKN8dMAH     2025-10-17  Lead  Non-Malaysian
# 1095586  00QMg00000CyjMjMAJ     2025-10-17  Lead      Malaysian
# 1069978  00QMg000007JXM3MAO     2025-10-17  Lead  Non-Malaysian
# 1095585  00QMg00000CyJ8vMAF     2025-10-17  Lead      Malaysian
# 1102918  00QMg00000E2mgQMAR     2025-10-17  Lead      Malaysian
# 1066447  00QIj000002AvO2MAK     2025-10-17  Lead      Malaysian
#
#                           name                             owner  \
# 1076445                  Elena               Alicia Yan Lyn Yeap
# 1102917          ElidrisiNoora               Alicia Yan Lyn Yeap
# 1083354         Liew Swee Kong  Firhin Asykil Mashi Zainul Mashi
# 1076446         Ting Xuan Kuan                        Ru Yi Khor
# 1083355          Fitri Nababan                 Dendi Fathul Hadi
# 1095586                   gayu     Nur Amelia Natasha Mohd Rozan
# 1069978  Ubayasiri Oneli Kayla                       Wan Yee Tan
# 1095585     Eunice Chee L. Ooi         Sharon Premkumari Pransis
# 1102918            Yogananthan     Nur Amelia Natasha Mohd Rozan
# 1066447                  Cheng                  Alvin Tan E-Sern
#
#                           owner_role bucket_role market_segment lead_source  \
# 1076445             ISR Support Team       OTHER  International      Online
# 1102917             ISR Support Team       OTHER  International      Online
# 1083354  Digital Engagement Advocate         DEC      New Local      Online
# 1076446        BD Northern Counselor    NORTHERN       Transfer   Called-In
# 1083355       ISR Region 1 Counselor         ISR  International      Online
# 1095586  Digital Engagement Advocate         DEC      New Local      Online
# 1069978       ISR Region 2 Counselor         ISR  International      Online
# 1095585            TU Counselor (PG)    SRE - PG      New Local      Online
# 1102918  Digital Engagement Advocate         DEC      New Local      Online
# 1066447            TU Counselor (PG)    SRE - PG       Transfer      Online
#
#          ...           lead_status opp_acc_id  opp_stage opp_programme_code  \
# 1076445  ...                  Warm       None       None              91614
# 1102917  ...                   New       None       None               None
# 1083354  ...                   New       None       None              13610
# 1076446  ...  Invalid (3 Attempts)       None       None              92602
# 1083355  ...                   New       None       None               None
# 1095586  ...                   New       None       None              86400
# 1069978  ...                  Lost       None       None              94607
# 1095585  ...                   New       None       None               None
# 1102918  ...                   New       None       None              92616
# 1066447  ...  Invalid (3 Attempts)       None       None               None
#
#                  online_source web_source_group web_source_grp  \
# 1076445     Digital Prospectus          Organic        ORGANIC
# 1102917           Enquiry Form          Organic        ORGANIC
# 1083354           Enquiry Form          Organic        ORGANIC
# 1076446                   None             None          Other
# 1083355  Lead Ads Social Media       Social Mix     SOCIAL MIX
# 1095586  Lead Ads Social Media       Social Mix     SOCIAL MIX
# 1069978                Chatbot              SEM            SEM
# 1095585  Lead Ads Social Media       Social Mix     SOCIAL MIX
# 1102918  Lead Ads Social Media       Social Mix     SOCIAL MIX
# 1066447     Digital Prospectus          Organic        ORGANIC
#
#                               entry_qualification  \
# 1076445  International Baccalaureate (IB) Diploma
# 1102917                                      None
# 1083354                          IGCSE / O-Levels
# 1076446                                   Diploma
# 1083355                                      None
# 1095586                                      None
# 1069978         Diploma of Hospitality Management
# 1095585                                      None
# 1102918                                      None
# 1066447                                   Masters
#
#                                             programme_name programme_code
# 1076445  Bachelor of Social Science (Honours) in Intern...          91614
# 1102917                                            Unknown           None
# 1083354                     Bachelor of Business (Honours)          93601
# 1076446           Bachelor of Quantity Surveying (Honours)          92602
# 1083355                  Doctor of Philosophy in Education          11812
# 1095586                              Diploma in Accounting          86400
# 1069978              Bachelor of Patisserie Arts (Honours)          94607
# 1095585                                      Master of Law          13715
# 1102918    Bachelor of Mechanical Engineering with Honours          92615
# 1066447                  Doctor of Philosophy in Education          11812
#
# [10 rows x 30 columns]

# %%
df['reporting_date']=df['reporting_date'].dt.strftime('%Y-%m-%d')

# %%
df['reporting_date'].dtypes
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# id                     object
# reporting_date         object
# type                   object
# record_type            object
# name                   object
# owner                  object
# owner_role             object
# bucket_role            object
# market_segment         object
# lead_source            object
# bucket_lead_source     object
# state                  object
# intake_year             int64
# intake_month           object
# cycle                  object
# campus_preference1     object
# vertical1              object
# level1                 object
# programme1             object
# race                   object
# lead_status            object
# opp_acc_id             object
# opp_stage              object
# opp_programme_code     object
# online_source          object
# web_source_group       object
# web_source_grp         object
# entry_qualification    object
# programme_name         object
# programme_code         object
# dtype: object

# %%
engine.dispose()
import os
from urllib.parse import quote
from sqlalchemy import create_engine
from dotenv import load_dotenv
 
def marcommdb_connection():
    # Load environment variables
    load_dotenv(override=True) 
 
    # Get credentials from environment variables
    username = os.getenv("PG_USERNAME")
    password = os.getenv("PG_PASSWORD")
    host = os.getenv("PG_HOST")
    port = os.getenv("PG_PORT")
    database = os.getenv("PG_DATABASE_EXPORT")
 
    # Ensure all credentials are available
    if not all([username, password, host, port, database]):
        raise ValueError("Missing one or more PostgreSQL environment variables!")
 
    # Encode password to handle special characters
    encoded_password = quote(password, safe="") if password else ""
 
    # Construct PostgreSQL connection string
    DATABASE_URL = f"postgresql+psycopg2://{username}:{encoded_password}@{host}:{port}/{database}"
 
    # Create and return SQLAlchemy engine
    return create_engine(DATABASE_URL)

# %%
engine= marcommdb_connection()

# %%
from sqlalchemy.types import Integer

df.to_sql(
    'leads_opp_staging',
    engine,
    schema='staging',
    if_exists='replace',
    index=False
)
# Out:
# 796
