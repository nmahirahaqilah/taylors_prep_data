# %%
from simple_salesforce import Salesforce
import pandas as pd
from dotenv import load_dotenv
from datetime import date, timedelta
from sqlalchemy import create_engine
from urllib.parse import quote_plus
from functools import lru_cache
import re
import os

# %%
load_dotenv()

username = os.getenv("PG_USERNAME")
password = os.getenv("PG_PASSWORD")
host = os.getenv("PG_HOST")
port = os.getenv("PG_PORT")
database = os.getenv("PG_DATABASE")

# URL-encode the password
encoded_password = quote_plus(password)

engine = create_engine(
    f"postgresql+psycopg2://{username}:{encoded_password}@{host}:{port}/{database}"
)

# %%
query = """
select distinct id,
       reporting_date,
       type,
       record_type,
       name,
       owner,
       owner_role,
       bucket_role,
       market_segment,
       lead_source, 
       bucket_lead_source,
       state,
       intake_year,
       intake_month,
       cycle,
       campus_preference1,
       vertical1,
       level1,
       programme1,
       race,
       lead_status,
       opp_acc_id,
       opp_stage,
       opp_programme_code,
       online_source,
       web_source_group,
       web_source_grp,
       entry_qualification
from sf_lead_opp_activity
where intake_year = 2024
and cycle in ('C1','C2','C3');
"""

# %%
C1C2C32024 = pd.read_sql(query, engine)

# %%
C1C2C32024['cycle'].value_counts()
# Out:
# cycle
# C3    2200376
# C2     629267
# C1     422855
# Name: count, dtype: int64

# %%
# --- Load files ---
first_tier  = pd.read_excel(r"C:/Users/112363/OneDrive - Taylor's Education Group/DWH_WIP/programme_code_mapping.xlsx", sheet_name="Tier1")
second_tier = pd.read_excel(r"C:/Users/112363/OneDrive - Taylor's Education Group/DWH_WIP/programme_code_mapping.xlsx", sheet_name="Tier2")
third_tier  = pd.read_excel(r"C:/Users/112363/OneDrive - Taylor's Education Group/DWH_WIP/programme_code_mapping.xlsx", sheet_name="Tier3")
fourth_tier = pd.read_excel(r"C:/Users/112363/OneDrive - Taylor's Education Group/DWH_WIP/programme_code_mapping.xlsx", sheet_name="Tier4")
odl_tier    = pd.read_excel(r"C:/Users/112363/OneDrive - Taylor's Education Group/DWH_WIP/programme_code_mapping.xlsx", sheet_name="ODL")

# %%
import re
import pandas as pd
from functools import lru_cache

# -------------------------
# 0) Normalize columns (vectorized)
# -------------------------
def normalize_cols(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    df.columns = df.columns.str.strip()
    return df

first_tier  = normalize_cols(first_tier)
second_tier = normalize_cols(second_tier)
third_tier  = normalize_cols(third_tier)
fourth_tier = normalize_cols(fourth_tier)
odl_tier    = normalize_cols(odl_tier)
data_df     = normalize_cols(C1C2C32024)

# Ensure intake_year column exists & numeric
if "intake_year" not in data_df.columns:
    for alt in ["Intake Year", "intakeyear", "IntakeYear"]:
        if alt in data_df.columns:
            data_df = data_df.rename(columns={alt: "intake_year"})
            break
if "intake_year" in data_df.columns:
    data_df["intake_year"] = pd.to_numeric(data_df["intake_year"], errors="coerce").astype("Int64")

# Lowercase helpers for consistent text compares
for col in ["programme1", "level1", "vertical1"]:
    if col in data_df.columns:
        data_df[col + "__lc"] = data_df[col].astype(str).str.lower()
        
# -------------------------
# 1) Year range parser (vectorized)
# -------------------------
def prepare_rule_tier(df_rules: pd.DataFrame) -> pd.DataFrame:
    df = df_rules.copy()
    if "Intake Year" in df.columns:
        # Accept "YYYY" or "YYYY-YYYY"
        yr = df["Intake Year"].astype(str).str.strip()
        span = yr.str.extract(r"^\s*(\d{4})\s*-\s*(\d{4})\s*$")
        single = yr.str.extract(r"^\s*(\d{4})\s*$")
        df["start_year"] = pd.to_numeric(span[0].fillna(single[0]), errors="coerce")
        df["end_year"]   = pd.to_numeric(span[1].fillna(single[0]), errors="coerce")
    return df

first_tier  = prepare_rule_tier(first_tier)
second_tier = prepare_rule_tier(second_tier)
third_tier  = prepare_rule_tier(third_tier)
fourth_tier = prepare_rule_tier(fourth_tier)
odl_tier    = prepare_rule_tier(odl_tier)

# -------------------------
# 2) Wildmatch helpers (cached + vectorized)
# -------------------------
@lru_cache(maxsize=2048)
def _compile_wildcard(pattern: str):
    esc = re.escape(str(pattern))
    esc = esc.replace(r"\*", ".*").replace(r"\?", ".")
    return re.compile(rf"^{esc}$", flags=re.IGNORECASE)

def series_wildmatch(series: pd.Series, patterns):
    """Vectorized 'wildmatch' across a Series for many patterns."""
    s = series.fillna("").astype(str)
    # Fast path: combine patterns into one big alternation regex if possible
    # (still uses per-pattern compile cache once)
    masks = []
    for p in patterns:
        masks.append(s.str.match(_compile_wildcard(p)))
    if not masks:
        return pd.Series(False, index=series.index)
    # OR all masks
    out = masks[0]
    for m in masks[1:]:
        out = out | m
    return out

# -------------------------
# 3) Compile each Programme_Code_Rule into a vectorized mask
# -------------------------
_wild_re = re.compile(
    r"wildmatch\s*\(\s*([A-Za-z_][A-Za-z0-9_]*)\s*,\s*([^)]+?)\s*\)",
    flags=re.IGNORECASE
)

def _parse_patterns(arg_text: str):
    # split comma-separated quoted patterns: 'a','b','c'
    # tolerate quotes " or '
    parts = re.findall(r"""(['"])(.*?)\1""", arg_text)
    return [p[1] for p in parts] if parts else []

def compile_rule_to_mask(rule_str: str, df: pd.DataFrame) -> pd.Series:
    """
    Turn a Qlik-like rule string into a vectorized boolean pandas Series.
    Supports:
      - wildmatch(col, 'pat1','pat2',...)
      - AND/OR/NOT (case-insensitive)
      - simple numeric/string comparisons against df columns (e.g. intake_year < 2022)
    """
    expr = str(rule_str).strip()
    expr = re.sub(r"\bAND\b", "&", expr, flags=re.IGNORECASE)
    expr = re.sub(r"\bOR\b",  "|", expr, flags=re.IGNORECASE)
    expr = re.sub(r"\bNOT\b", "~", expr, flags=re.IGNORECASE)

    masks = {}
    repls = []
    # Replace each wildmatch(...) with a placeholder variable name
    for i, m in enumerate(_wild_re.finditer(expr)):
        col = m.group(1)
        args = m.group(2)
        pats = _parse_patterns(args)
        placeholder = f"_WMASK_{i}_"
        repls.append((m.span(), placeholder, col, pats))

    # Build the final expression by splicing placeholders in reverse order
    expr_list = list(expr)
    for (start, end), placeholder, col, pats in reversed(repls):
        expr_list[start:end] = placeholder
        # choose lowercased column if present to be consistent
        col_use = col + "__lc" if (col + "__lc") in df.columns else col
        masks[placeholder] = series_wildmatch(df[col_use] if col_use in df.columns else pd.Series("", index=df.index), pats)

    final_expr = "".join(expr_list)

    # Create evaluation context: df columns as variables
    ctx = {c: df[c] for c in df.columns}
    ctx.update(masks)

    # Evaluate safely with pandas eval (python engine for Series ops)
    try:
        mask = pd.eval(final_expr, engine="python", local_dict=ctx)
        # Ensure boolean Series
        mask = mask.astype(bool)
    except Exception:
        # Fallback: nothing matches if expression fails
        mask = pd.Series(False, index=df.index)
    return mask

# -------------------------
# 4) Rule-tier evaluator (vectorized per rule, not per row)
# -------------------------
def apply_rule_tier(df_rules: pd.DataFrame, df: pd.DataFrame):
    """
    Returns two Series: name_out, code_out from a rule-based tier.
    First match wins (by row order in df_rules).
    """
    name_out = pd.Series(pd.NA, index=df.index, dtype="object")
    code_out = pd.Series(pd.NA, index=df.index, dtype="object")

    if not {"Programme_Code_Rule", "Programme Name"}.issubset(df_rules.columns):
        return name_out, code_out

    # Pre-extract code column existence
    has_code = "Programme Code" in df_rules.columns

    for _, r in df_rules.iterrows():
        mask = pd.Series(True, index=df.index)

        # Year filter
        if "start_year" in r and pd.notna(r["start_year"]) and "intake_year" in df.columns:
            mask &= df["intake_year"].between(int(r["start_year"]), int(r["end_year"]))

        # Rule expression
        rule = r["Programme_Code_Rule"]
        mask &= compile_rule_to_mask(rule, df)

        # Only fill where not already set
        to_fill = mask & name_out.isna()
        if to_fill.any():
            name_out.loc[to_fill] = r["Programme Name"]
            if has_code and pd.notna(r.get("Programme Code", pd.NA)):
                code_out.loc[to_fill] = str(r["Programme Code"])

        # Early exit if everything is filled
        if name_out.notna().all():
            break

    return name_out, code_out

# -------------------------
# 5) Mapping-tier evaluator (vectorized via maps/merges)
# -------------------------
def apply_mapping_tier(df_map: pd.DataFrame, df: pd.DataFrame):
    """
    Priority:
      1) (programme1, level1, vertical1)
      2) (programme1, level1)
      3) (programme1, vertical1)
      4) (programme1)
    Returns name_out, code_out Series.
    """
    name_out = pd.Series(pd.NA, index=df.index, dtype="object")
    code_out = pd.Series(pd.NA, index=df.index, dtype="object")
    if "Programme Name" not in df_map.columns:
        return name_out, code_out

    # Normalize lookup columns to lowercase
    m = df_map.copy()
    for k in ["programme1", "level1", "vertical1"]:
        if k in m.columns:
            m[k + "__lc"] = m[k].astype(str).str.lower()

    # Build keyed dicts and fill in priority order with .map (fast)
    def _map_by_keys(keys):
        # Only proceed if all keys exist in both df and map
        if not all((k + "__lc") in df.columns for k in keys):
            return
        if not all((k + "__lc") in m.columns for k in keys):
            return
        key_series = df[[k + "__lc" for k in keys]].astype(str).agg("|".join, axis=1)
        key_map = m.drop_duplicates(subset=[k + "__lc" for k in keys]).copy()
        key_map["__k__"] = key_map[[k + "__lc" for k in keys]].astype(str).agg("|".join, axis=1)
        name_dict = dict(zip(key_map["__k__"], key_map["Programme Name"]))
        code_dict = dict(zip(key_map["__k__"], key_map["Programme Code"])) if "Programme Code" in key_map.columns else {}

        fill_mask = name_out.isna()
        if fill_mask.any():
            ks = key_series.where(fill_mask)
            name_out.update(ks.map(name_dict))
            if code_dict:
                code_out.update(ks.map(code_dict))

    _map_by_keys(["programme1", "level1", "vertical1"])
    _map_by_keys(["programme1", "level1"])
    _map_by_keys(["programme1", "vertical1"])
    _map_by_keys(["programme1"])

    return name_out, code_out

# -------------------------
# 6) Apply tiers in priority order (fully vectorized)
# -------------------------
TIERS = [first_tier, second_tier, third_tier, fourth_tier, odl_tier]

out_name = pd.Series(pd.NA, index=data_df.index, dtype="object")
out_code = pd.Series(pd.NA, index=data_df.index, dtype="object")

for tier_df in TIERS:
    if "Programme_Code_Rule" in tier_df.columns:
        n, c = apply_rule_tier(tier_df, data_df)
    else:
        n, c = apply_mapping_tier(tier_df, data_df)

    fill = out_name.isna() & n.notna()
    if fill.any():
        out_name.loc[fill] = n.loc[fill]
        out_code.loc[fill] = c.loc[fill]

    # Early exit if all rows resolved
    if out_name.notna().all():
        break

# Fallbacks
out_name = out_name.fillna("Unknown")
out_code = out_code.astype("object")

data_df["programme_name"] = out_name
data_df["programme_code"] = out_code

# %%
data_df['programme_name'].value_counts()
# Out:
# programme_name
# Foundation in Business                                             536008
# Unknown                                                            319027
# Bachelor of Business (Honours)                                     207605
# Foundation in Arts                                                 132048
# General Certificate of Education - Advanced Level (GCE A Level)    117479
#                                                                     ...
# Bachelor of Business (Honours) in Finance and Economics                35
# MicroCred (BPA)                                                        33
# Bachelor of Business (Honours) in Banking and Finance                  27
# MicroCred (MAC)                                                        23
# MicroCred (BCM)                                                         2
# Name: count, Length: 118, dtype: int64

# %%
data_df.tail(10)
# Out:
#                          id reporting_date  type    record_type  \
# 3252488  00QMg000006YgnlMAC     2024-12-27  Lead      Malaysian
# 3252489  00QMg000006YSPrMAO     2024-12-20  Lead      Malaysian
# 3252490  00QMg000006YX9QMAW     2024-12-20  Lead  Non-Malaysian
# 3252491  00QMg000006YX9QMAW     2024-12-27  Lead  Non-Malaysian
# 3252492  00QMg000006Z7b6MAC     2024-12-27  Lead      Malaysian
# 3252493  00QMg000006Zad3MAC     2024-12-27  Lead      Malaysian
# 3252494  00QMg000006ZEPdMAO     2024-12-27  Lead  Non-Malaysian
# 3252495  00QMg000006ZGEXMA4     2024-12-27  Lead  Non-Malaysian
# 3252496  00QMg000006ZGuTMAW     2024-12-27  Lead      Malaysian
# 3252497  00QMg000006Zzd6MAC     2024-12-27  Lead  Non-Malaysian
#
#                                    name                  owner  \
# 3252488             MahaletchumyMurugan           Aimi Shazani
# 3252489             MahaletchumyMurugan           Aimi Shazani
# 3252490                    Kristine Afi        ISR Ops Support
# 3252491                    Kristine Afi                   Yeap
# 3252492                   yap Sook Miun                   Khor
# 3252493                              Lo           Aimi Shazani
# 3252494                   Muhammad Atif                    Yap
# 3252495                           Bahar                    Yap
# 3252496  MUHAMMAD ASHRAF BON ABD RAHMAN                   Khor
# 3252497                Tharaoh Al-kebsi  Terrence Len Wei Hian
#
#                      owner_role bucket_role market_segment lead_source  ...  \
# 3252488   TU Sales Manager (PG)    SRE - PG      New Local      Online  ...
# 3252489   TU Sales Manager (PG)    SRE - PG      New Local      Online  ...
# 3252490        ISR Support Team       OTHER  International      Online  ...
# 3252491        ISR Support Team       OTHER  International      Online  ...
# 3252492   BD Northern Counselor    NORTHERN      New Local      Online  ...
# 3252493   TU Sales Manager (PG)    SRE - PG      New Local      Online  ...
# 3252494  ISR Region 1 Counselor         ISR  International      Online  ...
# 3252495  ISR Region 1 Counselor         ISR  International      Online  ...
# 3252496   BD Northern Counselor    NORTHERN      New Local      Online  ...
# 3252497  ISR Region 5 Counselor         ISR  International      Online  ...
#
#         opp_programme_code       online_source  web_source_group  \
# 3252488              11721  Digital Prospectus           Organic
# 3252489              11721  Digital Prospectus           Organic
# 3252490              44003  Digital Prospectus           Organic
# 3252491              44003  Digital Prospectus           Organic
# 3252492               None        Enquiry Form           Organic
# 3252493              44003  Digital Prospectus           Organic
# 3252494              12803  Digital Prospectus           Organic
# 3252495              12701  Digital Prospectus           Organic
# 3252496               None        Enquiry Form           Organic
# 3252497              12703  Digital Prospectus           Organic
#
#         web_source_grp entry_qualification  \
# 3252488        ORGANIC              Degree
# 3252489        ORGANIC              Degree
# 3252490        ORGANIC              Degree
# 3252491        ORGANIC              Degree
# 3252492        ORGANIC                None
# 3252493        ORGANIC              Degree
# 3252494        ORGANIC             Masters
# 3252495        ORGANIC             Diploma
# 3252496        ORGANIC                None
# 3252497        ORGANIC              Degree
#
#                                    programme1__lc  \
# 3252488           master of teaching and learning
# 3252489           master of teaching and learning
# 3252490         master of business administration
# 3252491         master of business administration
# 3252492                                      none
# 3252493         master of business administration
# 3252494  doctor of philosophy in computer science
# 3252495                master of computer science
# 3252496                                      none
# 3252497               master of applied computing
#
#                                level1__lc         vertical1__lc  \
# 3252488              online learning - tu  online learning - tu
# 3252489              online learning - tu  online learning - tu
# 3252490              online learning - tu  online learning - tu
# 3252491              online learning - tu  online learning - tu
# 3252492                              none                  none
# 3252493              online learning - tu  online learning - tu
# 3252494     postgraduate phd - socit - tu        computing - tu
# 3252495  postgraduate master - socit - tu        computing - tu
# 3252496                              none                  none
# 3252497              online learning - tu  online learning - tu
#
#                                    programme_name programme_code
# 3252488                                   Unknown           <NA>
# 3252489                                   Unknown           <NA>
# 3252490         Master of Business Administration          44003
# 3252491         Master of Business Administration          44003
# 3252492                                   Unknown           <NA>
# 3252493         Master of Business Administration          44003
# 3252494  Doctor of Philosophy in Computer Science          12803
# 3252495                Master of Computer Science          12701
# 3252496                                   Unknown           <NA>
# 3252497               Master of Applied Computing          12703
#
# [10 rows x 33 columns]

# %%
data_df.drop(['programme1__lc','level1__lc','vertical1__lc'], axis=1, inplace=True)

# %%
engine.dispose()
import os
from urllib.parse import quote
from sqlalchemy import create_engine
from dotenv import load_dotenv
 
def marcommdb_connection():
    # Load environment variables
    load_dotenv(override=True) 
 
    # Get credentials from environment variables
    username = os.getenv("PG_USERNAME")
    password = os.getenv("PG_PASSWORD")
    host = os.getenv("PG_HOST")
    port = os.getenv("PG_PORT")
    database = os.getenv("PG_DATABASE_EXPORT")
 
    # Ensure all credentials are available
    if not all([username, password, host, port, database]):
        raise ValueError("Missing one or more PostgreSQL environment variables!")
 
    # Encode password to handle special characters
    encoded_password = quote(password, safe="") if password else ""
 
    # Construct PostgreSQL connection string
    DATABASE_URL = f"postgresql+psycopg2://{username}:{encoded_password}@{host}:{port}/{database}"
 
    # Create and return SQLAlchemy engine
    return create_engine(DATABASE_URL)

# %%
engine= marcommdb_connection()

# %%
from sqlalchemy.types import Integer

data_df.to_sql(
    'leads_opp_staging',
    engine,
    schema='staging',
    if_exists='replace',
    index=False
)
# Out:
# 498

# %%
unknown_df = data_df[data_df['programme_name'] == 'Unknown']

# %%
unknown_df[['level1','vertical1','programme1','programme_name','intake_year','cycle']].value_counts()
# Out:
# level1                                             vertical1                                              programme1                                                                         programme_name  intake_year  cycle
# Online Learning - TU                               Online Learning - TU                                   Master of Teaching and Learning                                                    Unknown         2024         C3       9140
#                                                                                                                                                                                                                           C2       3607
# Pre-University                                     School of Pre-University Studies                       General Certificate of Education - Advanced Level (GCE A Level)                    Unknown         2024         C3       3515
# Postgraduate Master - SOED - TU - Online Learning  Online Learning - TU                                   Master of Teaching and Learning                                                    Unknown         2024         C2       3008
# Online Learning - TU                               Online Learning - TU                                   Master of Teaching and Learning                                                    Unknown         2024         C1       1854
#                                                                                                           (PGOL-HOSP)2024_C2_TU_PAID_SOCIAL_LOCAL_LEADGEN_PGOL-HOSPv2                        Unknown         2024         C2       1318
# Undergraduate                                      Engineering - TU                                       Bachelor of Electrical and Electronic Engineering with Honours                     Unknown         2024         C3       1260
# Online Learning - TU                               Online Learning - TU                                   (PGOL-HOSP)2024_C2_TU_PAID_SOCIAL_LOCAL_LEADGEN_PGOL-HOSPv2                        Unknown         2024         C3       1036
# Postgraduate Master - SOED - TU - Online Learning  Online Learning - TU                                   Master of Teaching and Learning                                                    Unknown         2024         C3        959
# Pre-University                                     School of Pre-University Studies                       General Certificate of Education - Advanced Level (GCE A Level)                    Unknown         2024         C2        586
#                                                                                                                                                                                                                           C1        473
# Undergraduate                                      Communication - TU                                     Bachelor of Mass Communication (Honours) in Public Relations and Event Management  Unknown         2024         C3        398
#                                                    Engineering - TU                                       Bachelor of Electrical and Electronic Engineering with Honours                     Unknown         2024         C2        392
#                                                    Communication - TU                                     Bachelor of Mass Communication (Honours) in Advertising and Brand Management       Unknown         2024         C3        290
# Pre-U -SoPU- TC                                    Pre-U - TC                                             General Certificate of Education - Advanced Level (GCE A Level)                    Unknown         2024         C3        201
# Undergraduate                                      Engineering - TU                                       Bachelor of Electrical and Electronic Engineering with Honours                     Unknown         2024         C1        177
# Foundation - TBS - TC                              Pre-U - TC                                             General Certificate of Education - Advanced Level (GCE A Level)                    Unknown         2024         C3        135
# Online Learning - TU                               Online Learning - TU                                   Postgraduate                                                                       Unknown         2024         C3        113
# Others - TC                                        Business - TU                                          General Certificate of Education - Advanced Level (GCE A Level)                    Unknown         2024         C3         80
#                                                    Professional - TC                                      General Certificate of Education - Advanced Level (GCE A Level)                    Unknown         2024         C3         78
#                                                    Pre-U - TC                                             General Certificate of Education - Advanced Level (GCE A Level)                    Unknown         2024         C3         62
# Online Learning - TU                               Online Learning - TU                                   General Certificate of Education - Advanced Level (GCE A Level)                    Unknown         2024         C3         60
# Undergraduate                                      Communication - TU                                     Bachelor of Mass Communication (Hons) in Advertising and Brand Management          Unknown         2024         C3         57
#                                                                                                           Bachelor of Mass Communication (Honours) in Public Relations and Event Management  Unknown         2024         C2         55
# Online Learning - TU                               Online Learning - TU                                   Postgraduate                                                                       Unknown         2024         C2         52
# Foundation - TBS - TC                              Pre-U - TC                                             General Certificate of Education - Advanced Level (GCE A Level)                    Unknown         2024         
# Step 1. Create counts DataFrame
unknown_counts = (
    unknown_df[['level1', 'vertical1', 'programme1']]
    .value_counts()
    .reset_index(name='count')
)

# Step 2. Sort by count descending, then programme name ascending
unknown_counts = unknown_counts.sort_values(
    by=['count', 'programme1'],
    ascending=[False, True]
)

# Step 3. Display all rows
pd.set_option('display.max_rows', None)

# Step 4. Show the result
unknown_counts
# Out:
#                                                level1  \
# 0                                Online Learning - TU
# 1                                      Pre-University
# 2   Postgraduate Master - SOED - TU - Online Learning
# 3                                Online Learning - TU
# 4                                       Undergraduate
# 5                                       Undergraduate
# 6                                       Undergraduate
# 7                               Foundation - TBS - TC
# 8                                     Pre-U -SoPU- TC
# 9                                Online Learning - TU
# 10                                        Others - TC
# 11                                        Others - TC
# 12                               Online Learning - TU
# 13                              Foundation Programmes
# 14                                        Others - TC
# 15                                      Undergraduate
# 16                                      Undergraduate
# 17                                      Undergraduate
# 18                              Foundation - SOC - TC
# 19                            Foundation - SOCIT - TC
# 20                                            Diploma
# 21                               Online Learning - TU
# 22                                     Pre-University
# 23                                     Pre-University
# 24                                 Diploma - SOC - TC
# 25                               Online Learning - TU
# 26                                                 UG
# 29                                International Pre-U
# 27                              Foundation - SBS - TC
# 28                                 Diploma - SOC - TC
# 30                                      Undergraduate
# 31                                      Undergraduate
# 32                                      Undergraduate
# 33                                        Others - TC
# 34                                        Others - TC
# 36                                        Others - TC
# 35                                   Pre-U - CAL - TC
# 37                                        Others - TC
# 38                               Online Learning - TU
# 39                                        Others - TC
# 40                                            Diploma
# 42                                                 UG
# 44                                                 PU
# 41                                                 UG
# 43                                                 UG
# 45                                   Pre-U - CAL - TC
# 46                                      Undergraduate
# 47                               Online Learning - TU
# 48                               Online Learning - TU
# 49                               Online Learning - TU
# 50                               Online Learning - TU
# 51                               Online Learning - TU
# 52                               Online Learning - TU
# 54                                      Undergraduate
# 53                              Foundation - SOE - TC
# 55                                        Others - TC
# 58                                      Undergraduate
# 57                               Online Learning - TU
# 56                                      Undergraduate
# 59                                                 PG
# 60                                 Diploma - TBS - TC
# 61                                 Degree - SLAS - TU
# 62                                     Pre-University
# 63                                      Undergraduate
# 64                                     Pre-University
# 67                                   Pre-U - CAL - TC
# 65                               Online Learning - TU
# 68                                        Others - TC
# 66                                  Pre-U - SACE - TC
# 69                                 Diploma - TCI - TU
# 71                                        Others - TC
# 70                                        Others - TC
# 73                               Online Learning - TU
# 72                               Online Learning - TU
#
#                                             vertical1  \
# 0                                Online Learning - TU
# 1                    School of Pre-University Studies
# 2                                Online Learning - TU
# 3                                Online Learning - TU
# 4                                    Engineering - TU
# 5                                  Communication - TU
# 6                                  Communication - TU
# 7                                          Pre-U - TC
# 8                                          Pre-U - TC
# 9                                Online Learning - TU
# 10                                      Business - TU
# 11                                  Professional - TC
# 12                               Online Learning - TU
# 13                              Foundation Programmes
# 14                                         Pre-U - TC
# 15                                 Communication - TU
# 16                                   Engineering - TU
# 17                                   Engineering - TU
# 18                                   Hotel Management
# 32                                   Bachelors Degree     29
# 33  General Certificate of Education - Advanced Le...     27
# 34  General Certificate of Education - Advanced Le...     27
# 36  Bachelor of Electrical and Electronic Engineer...     26
# 35  General Certificate of Education - Advanced Le...     26
# 37  General Certificate of Education - Advanced Le...     24
# 38                                  Bachelor's Degree     23
# 39  General Certificate of Education - Advanced Le...     23
# 40                               Professional Studies     23
# 42       Bachelor of Accounting and Finance (Honours)     22
# 44  Bachelor of Electrical and Electronic Engineer...     22
# 41        Bachelor of Finance and Economics (Honours)     22
# 43                                   Bachelors Degree     22
# 45  Bachelor of Electrical and Electronic Engineer...     21
# 46                                            Diploma     20
# 47                      Postgraduate (Master's & PhD)     18
# 48                                          education     16
# 49               International Business and Marketing     14
# 50               International Hospitality Management     14
# 51                Electrical & Electronic Engineering     11
# 52                               Master of Management     11
# 54                                           February      8
# 53  General Certificate of Education - Advanced Le...      8
# 55  General Certificate of Education - Advanced Le...      8
# 58                                              April      6
# 57                    Master of Teaching and Learning      6
# 56                                          September      6
# 59  Bachelor of Business (Honours) in Finance and ...      5
# 60  General Certificate of Education - Advanced Le...      5
# 61                                   Bachelors Degree      4
# 62  General Certificate of Education - Advanced Le...      3
# 63                               Professional Studies      3
# 64                               Professional Studies      3
# 67                                Banking and Finance      2
# 65                                            Diploma      2
# 68  General Certificate of Education - Advanced Le...      2
# 66              Public Relations and Event Management      2
# 69  General Certificate of Education - Advanced Le...      1
# 71  General Certificate of Education - Advanced Le...      1
# 70                               Professional Studies      1
# 73                                         Psychology      1
# 72                                           business      1

# %%
grouped_detail = (
    unknown_df
    .groupby(['programme1', 'level1', 'vertical1'])
    .size()
    .reset_index(name='count')
    .sort_values(by=['programme1', 'count'], ascending=[True, True])
)

pd.set_option('display.max_rows', None)
grouped_detail
# Out:
#                                            programme1  \
# 0   (PGOL-HOSP)2024_C2_TU_PAID_SOCIAL_LOCAL_LEADGE...
# 1                                               April
# 2        Bachelor of Accounting and Finance (Honours)
# 3   Bachelor of Business (Honours) in Finance and ...
# 6   Bachelor of Electrical and Electronic Engineer...
# 5   Bachelor of Electrical and Electronic Engineer...
# 4   Bachelor of Electrical and Electronic Engineer...
# 7   Bachelor of Electrical and Electronic Engineer...
# 8   Bachelor of Electrical and Electronic Engineer...
# 9         Bachelor of Finance and Economics (Honours)
# 10  Bachelor of Mass Communication (Honours) in Ad...
# 11  Bachelor of Mass Communication (Honours) in Pu...
# 12  Bachelor of Mass Communication (Hons) in Adver...
# 13  Bachelor of Mass Communication（Hons）Public Rel...
# 14                                  Bachelor's Degree
# 15                                  Bachelor's Degree
# 16                                   Bachelors Degree
# 18                                   Bachelors Degree
# 19                                   Bachelors Degree
# 21                                   Bachelors Degree
# 17                                   Bachelors Degree
# 20                                   Bachelors Degree
# 22                                Banking and Finance
# 23                                   Cambrige A Level
# 26                                            Diploma
# 27                                            Diploma
# 24                                            Diploma
# 25                                            Diploma
# 28                Electrical & Electronic Engineering
# 29                                           February
# 30                           Foundation in Accounting
